# %% [markdown]
# Not Defteri - Grokking Algorithms

# %% [markdown]
# Binary Search - basic

# %%
def binary_search(list, item):
  low = 0
  high = len(list) - 1

  while low <= high:
    mid = (low + high) // 2
    guess = list[mid]

    if guess == item:
      return mid
    if guess > item:
      high = mid - 1
    else:
      low = mid + 1
  return None

my_list = [1,3,5,7,9]

print(binary_search(my_list, 3))
print(binary_search(my_list, -1))
# Out:
# 1
# None

# %%
def binary_arama(list1, item1):
  low = 0
  high = len(list1) - 1
  while low <= high:
    mid = (low + high) // 2
    guess = list1[mid]
    if guess == item1:
      return mid
    if guess < item1:
      low = mid + 1
    else:
      high = mid - 1
  return None

ma_list = [1,3,4,5,6,7,8,9,12,14,57,68]

print(binary_arama(ma_list,5))
print(binary_arama(ma_list,68))
# Out:
# 3
# 11

# %%
def findSmallest(arr):
  smallest = arr[0]
  smallest_index = 0
  for i in range(1, len(arr)):
    if arr[i] < smallest:
      smallest = arr[i]
      smallest_index = i
  return smallest_index

def selectionSort(arr):
  newArr = []
  for i in range(len(arr)):
    smallest = findSmallest(arr)
    newArr.append(arr.pop(smallest))
  return newArr

print(selectionSort([5, 3, 2, 6, 10,0,7, -1]))
# Out:
# [-1, 0, 2, 3, 5, 6, 7, 10]

# %%
# we gonna write a definition(def) to find every small integer in our list because if we wanna put smallest to first place, we need to do.
def minsta(array1):
  # defining smallest item from the beggining, then we gonna compare with other items in list.
  # always set the current minimum to first item in list
  minst = array1[0]
  # we takin' index (items order in list or array) because we gonna use the index to re-assing the items in our list to a new ordered array.
  minst_index = 0 
  for i in range(1,len(array1)):
    if array1[i] < minst:
      minst = array1[i]
      minst_index = i
  return minst_index

def selectionSort(array1):
  newArray = []
  for i in range(len(array1)):
    smallest = minsta(array1)
    newArray.append(array1.pop(smallest))
  return newArray

print(selectionSort([2,4,6,7,9,5,0,10,32,544,343]))
# Out:
# [0, 2, 4, 5, 6, 7, 9, 10, 32, 343, 544]
